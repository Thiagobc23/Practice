# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bra = pd.read_csv('bra.csv', dtype = {'b': np.int32}, index_col = 'Indicator Name')
bra.head()
# Out:
#                 Population ages 40-44, male (% of male population)  \
# Indicator Name
# 1997                                                     5.913656
# 1998                                                     5.981123
# 1999                                                     6.058478
# 2000                                                     6.152822
# 2001                                                     6.252224
#
#                 Population ages 40-44, female (% of female population)  \
# Indicator Name
# 1997                                                     6.042993
# 1998                                                     6.117614
# 1999                                                     6.202496
# 2000                                                     6.305154
# 2001                                                     6.414866
#
#                 Population ages 35-39, male (% of male population)  \
# Indicator Name
# 1997                                                     7.026780
# 1998                                                     7.135816
# 1999                                                     7.222697
# 2000                                                     7.275879
# 2001                                                     7.293668
#
#                 Population ages 35-39, female (% of female population)  \
# Indicator Name
# 1997                                                     7.130799
# 1998                                                     7.250664
# 1999                                                     7.347304
# 2000                                                     7.408327
# 2001                                                     7.431803
#
#                 Population ages 30-34, male (% of male population)  \
# Indicator Name
# 1997                                                     7.997331
# 1998                                                     7.946985
# 1999                                                     7.892991
# 2000                                                     7.846759
# 2001                                                     7.801507
#
#                 Population ages 30-34, female (% of female population)  \
# Indicator Name
# 1997                                                     8.066923
# 1998                                                     8.018675
# 1999                                                     7.963017
# 2000                                                     7.911024
# 2001                                                     7.854891
#
#                 Population ages 25-29, male (% of male population)  \
# Indicator Name
# 1997                                                     8.491600
# 1998                                                     8.438342
# 1999                                                     8.415183
# 2000                                                     8.430924
# 2001                                                     8.476687
#
#                 Population ages 25-29, female (% of female population)  \
# Indicator Name
# 1997                                                     8.451754
# 1998                                                     8.382154
# 1999                                                     8.339884
# 2000                                                     8.333891
# 2001                                                     8.354741
#
#                 Population ages 20-24, male (% of male population)  \
# Indicator Name
# 1997                                                     9.336325
# 1998                                                     9.419960
# 1999                                                     9.511770
# 2000                                                     9.601946
# 2001                                                     9.679602
#
#                 Population ages 20-24, female (% of female population)  ...  \
# Indicator Name                                                          ...
# 1997                                                     9.096745       ...
# 1998                                                     9.154362       ...
# 1999                                                     9.219809       ...
# 2000                                                     9.283203       ...
# 2001                                                     9.339168       ...
#
#                 Employment in services, male (% of male employment) (modeled ILO estimate)  \
# Indicator Name
# 1997                                                    46.737999
# 1998                                                    47.319000
# 1999                                                    47.646999
# 2000                                                    49.013000
# 2001                                                    49.754002
#
#                 Domestic credit to private sector (% of GDP)  \
# Indicator Name
# 1997                                               40.852237
# 1998                                               29.532261
# 1999                                               29.826910
# 2000                                               31.140986
# 2001                                               29.004038
#
#                 Domestic credit provided by financial sector (% of GDP)  \
# Indicator Name
# 1997                                                    58.635279
# 1998                                                    65.247877
# 1999                                                    69.403668
# 2000                                                    70.681245
# 2001                                                    72.865149
#
#                 Wholesale price index (2010 = 100)  \
# Indicator Name
# 1997                                     28.113599
# 1998                                     29.109776
# 1999                                     33.933370
# 2000                                     40.076461
# 2001                                     45.131622
#
#                 Inflation, consumer prices (annual %)  \
# Indicator Name
# 1997                                         6.926713
# 1998                                         3.195076
# 1999                                         4.858447
# 2000                                         7.044141
# 2001                                         6.840359
#
#                 Consumer price index (2010 = 100)  \
# Indicator Name
# 1997                                    45.351868
# 1998                                    46.800895
# 1999                                    49.074692
# 2000                                    52.531583
# 2001                                    56.124932
#
#                 Total reserves minus gold (current US$)  \
# Indicator Name
# 1997                                       5.132950e+10
# 1998                                       4.316475e+10
# 1999                                       3.527932e+10
# 2000                                       3.243398e+10
# 2001                                       3.556304e+10
#
#                 Total reserves in months of imports  \
# Indicator Name
# 1997                                       6.470326
# 1998                                       5.395330
# 1999                                       5.095492
# 2000                                       4.256237
# 2001                                       4.547309
#
#                 Total reserves (% of total external debt)  \
# Indicator Name
# 1997                                            26.238036
# 1998                                            18.383258
# 1999                                            14.826644
# 2000                                            13.613900
# 2001                                            15.596838
#
#                 Total reserves (includes gold, current US$)
# Indicator Name
# 1997                                           5.220852e+10
# 1998                                           4.448719e+10
# 1999                                           3.634232e+10
# 2000                                           3.301530e+10
# 2001                                           3.586645e+10
#
# [5 rows x 392 columns]

# %%
list(bra)
# Out:
# ['Population ages 40-44, male (% of male population)',
#  'Population ages 40-44, female (% of female population)',
#  'Population ages 35-39, male (% of male population)',
#  'Population ages 35-39, female (% of female population)',
#  'Population ages 30-34, male (% of male population)',
#  'Population ages 30-34, female (% of female population)',
#  'Population ages 25-29, male (% of male population)',
#  'Population ages 25-29, female (% of female population)',
#  'Population ages 20-24, male (% of male population)',
#  'Population ages 20-24, female (% of female population)',
#  'Population ages 15-64 (% of total)',
#  'Population ages 15-64, total',
#  'Population ages 15-64, male (% of total)',
#  'Population ages 15-64, male',
#  'Population ages 15-64, female (% of total)',
#  'Population ages 15-64, female',
#  'Population ages 15-19, male (% of male population)',
#  'Population ages 15-19, female (% of female population)',
#  'Population ages 10-14, male (% of male population)',
#  'Population ages 10-14, female (% of female population)',
#  'Population ages 5-9, male (% of male population)',
#  'Population ages 5-9, female (% of female population)',
#  'Population ages 0-14 (% of total)',
#  'Population ages 0-14, total',
#  'Population ages 0-14, male (% of total)',
#  'Population ages 0-14, male',
#  'Population ages 0-14, female (% of total)',
#  'Population ages 0-14, female',
#  'Population ages 0-4, male (% of male population)',
#  'Population ages 0-4, female (% of female population)',
#  'Survival to age 65, male (% of cohort)',
#  'Survival to age 65, female (% of cohort)',
#  'Fertility rate, total (births per woman)',
#  'Life expectancy at birth, male (years)',
#  'Life expectancy at birth, total (years)',
#  'Life expectancy at birth, female (years)',
#  'Mortality rate, infant (per 1,000 live births)',
#  'Death rate, crude (per 1,000 people)',
#  'Birth rate, crude (per 1,000 people)',
#  'Mortality rate, adult, male (per 1,000 male adults)',
#  'Mortality rate, adult, female (per 1,000 female adults)',
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#  'Primary education, pupils',
#  'Real effective exchange rate index (2010 = 100)',
#  'Subsidies and other transfers (% of expense)',
#  'Subsidies and other transfers (current LCU)',
#  'Expense (% of GDP)',
#  'Expense (current LCU)',
#  'Interest payments (% of expense)',
#  'Interest payments (% of revenue)',
#  'Interest payments (current LCU)',
#  'Goods and services expense (% of expense)',
#  'Goods and services expense (current LCU)',
#  'Compensation of employees (% of expense)',
#  'Compensation of employees (current LCU)',
#  'Taxes on income, profits and capital gains (% of total taxes)',
#  'Taxes on income, profits and capital gains (% of revenue)',
#  'Taxes on income, profits and capital gains (current LCU)',
#  'Tax revenue (% of GDP)',
#  'Tax revenue (current LCU)',
#  'Other taxes (% of revenue)',
#  'Other taxes (current LCU)',
#  'Taxes on international trade (% of revenue)',
#  'Taxes on international trade (current LCU)',
#  'Customs and other import duties (% of tax revenue)',
#  'Customs and other import duties (current LCU)',
#  'Taxes on goods and services (% value added of industry and services)',
#  'Taxes on goods and services (% of revenue)',
#  'Taxes on goods and services (current LCU)',
#  'Revenue, excluding grants (% of GDP)',
#  'Revenue, excluding grants (current LCU)',
#  'Social contributions (% of revenue)',
#  'Social contributions (current LCU)',
#  'Grants and other revenue (% of revenue)',
#  'Net official flows from UN agencies, IFAD (current US$)',
#  'Net flows on external debt, short-term (NFL, current US$)',
#  'Net flows on external debt, public and publicly guaranteed (PPG) (NFL, current US$)',
#  'Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#  'Net flows on external debt, long-term (NFL, current US$)',
#  'Net flows on external debt, total (NFL, current US$)',
#  'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)',
#  'PPG, bilateral concessional (NFL, current US$)',
#  'Net financial flows, bilateral (NFL, current US$)',
#  'Average maturity on new external debt commitments, private (years)',
#  'Average maturity on new external debt commitments, official (years)',
#  'Average maturity on new external debt commitments (years)',
#  'Interest arrears, private creditors (current US$)',
#  'Interest arrears, official creditors (current US$)',
#  'Net change in interest arrears (current US$)',
#  'Interest arrears, long-term DOD (US$)',
#  'PPG, private creditors (INT, current US$)',
#  'PPG, other private creditors (INT, current US$)',
#  'PNG, commercial banks and other creditors (INT, current US$)',
#  'PNG, bonds (INT, current US$)',
#  'PPG, commercial banks (INT, current US$)',
#  'PPG, bonds (INT, current US$)',
#  'PPG, official creditors (INT, current US$)',
#  'PPG, multilateral concessional (INT, current US$)',
#  'PPG, multilateral (INT, current US$)',
#  'Travel services (% of commercial service exports)',
#  'Transport services (% of commercial service exports)',
#  'High-technology exports (% of manufactured exports)',
#  'High-technology exports (current US$)',
#  'Commercial service exports (current US$)',
#  'Computer, communications and other services (% of commercial service exports)',
#  'Export value index (2000 = 100)',
#  'Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#  'Merchandise exports by the reporting economy (current US$)',
#  'Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#  'Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#  'Merchandise exports to high-income economies (% of total merchandise exports)',
#  'Merchandise exports (current US$)',
#  'Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#  'Ores and metals exports (% of merchandise exports)',
#  'Manufactures exports (% of merchandise exports)',
#  'Insurance and financial services (% of commercial service exports)',
#  'Fuel exports (% of merchandise exports)',
#  'Food exports (% of merchandise exports)',
#  'Agricultural raw materials exports (% of merchandise exports)',
#  'Export unit value index (2000 = 100)',
#  'Export volume index (2000 = 100)',
#  'Medium and high-tech exports (% manufactured exports)',
#  'Net barter terms of trade index (2000 = 100)',
#  'Travel services (% of commercial service imports)',
#  'Transport services (% of commercial service imports)',
#  'Commercial service imports (current US$)',
#  'Computer, communications and other services (% of commercial service imports)',
#  'Import value index (2000 = 100)',
#  'Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
#  'Merchandise imports by the reporting economy (current US$)',
#  'Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#  'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#  'Final consumption expenditure (constant 2010 US$)',
#  'Final consumption expenditure (current LCU)',
#  'Final consumption expenditure (current US$)',
#  'Households and NPISHs final consumption expenditure (% of GDP)',
#  'Households and NPISHs Final consumption expenditure, PPP (constant 2011 international $)',
#  'Households and NPISHs Final consumption expenditure, PPP (current international $)',
#  'Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#  'Households and NPISHs Final consumption expenditure per capita (constant 2010 US$)',
#  'Households and NPISHs Final consumption expenditure (constant LCU)',
#  'Households and NPISHs Final consumption expenditure (annual % growth)',
#  'Households and NPISHs Final consumption expenditure (constant 2010 US$)',
#  'Households and NPISHs Final consumption expenditure (current LCU)',
#  'Households and NPISHs Final consumption expenditure (current US$)',
#  'General government final consumption expenditure (% of GDP)',
#  'General government final consumption expenditure (constant LCU)',
#  'General government final consumption expenditure (annual % growth)',
#  'General government final consumption expenditure (constant 2010 US$)',
#  'General government final consumption expenditure (current LCU)',
#  'General government final consumption expenditure (current US$)',
#  'Arms exports (SIPRI trend indicator values)',
#  'Military expenditure (% of general government expenditure)',
#  'Military expenditure (% of GDP)',
#  'Military expenditure (current LCU)',
#  'Military expenditure (current USD)',
#  'Armed forces personnel (% of total labor force)',
#  'Armed forces personnel, total',
#  'Arms imports (SIPRI trend indicator values)',
#  'Stocks traded, total value (% of GDP)',
#  'Stocks traded, total value (current US$)',
#  'Listed domestic companies, total',
#  'S&P Global Equity Indices (annual % change)',
#  'Personal remittances, received (% of GDP)',
#  'Personal remittances, received (current US$)',
#  'Personal transfers, receipts (BoP, current US$)',
#  'Secondary income receipts (BoP, current US$)',
#  'Portfolio equity, net inflows (BoP, current US$)',
#  'Primary income on FDI, payments (current US$)',
#  'Foreign direct investment, net inflows (% of GDP)',
#  'Foreign direct investment, net inflows (BoP, current US$)',
#  'Travel services (% of service exports, BoP)',
#  'Transport services (% of service exports, BoP)',
#  'Exports of goods, services and primary income (BoP, current US$)',
#  'Charges for the use of intellectual property, receipts (BoP, current US$)',
#  'Service exports (BoP, current US$)',
#  'Goods exports (BoP, current US$)',
#  'Insurance and financial services (% of service exports, BoP)',
#  'Exports of goods and services (BoP, current US$)',
#  'Primary income receipts (BoP, current US$)',
#  'Communications, computer, etc. (% of service exports, BoP)',
#  'ICT service exports (% of service exports, BoP)',
#  'ICT service exports (BoP, current US$)',
#  'Technical cooperation grants (BoP, current US$)',
#  'Grants, excluding technical cooperation (BoP, current US$)',
#  'Net secondary income (BoP, current US$)',
#  'Reserves and related items (BoP, current US$)',
#  'Portfolio investment, net (BoP, current US$)',
#  'Foreign direct investment, net (BoP, current US$)',
#  'Net errors and omissions (BoP, current US$)',
#  'Net trade in goods (BoP, current US$)',
#  'Net trade in goods and services (BoP, current US$)',
#  'Net primary income (BoP, current US$)',
#  'Net financial account (BoP, current US$)',
#  'Current account balance (% of GDP)',
#  'Current account balance (BoP, current US$)',
#  'Ores and metals imports (% of merchandise imports)',
#  'Manufactures imports (% of merchandise imports)',
#  'Insurance and financial services (% of commercial service imports)',
#  'Fuel imports (% of merchandise imports)',
#  'Food imports (% of merchandise imports)',
#  'Agricultural raw materials imports (% of merchandise imports)',
#  'Import unit value index (2000 = 100)',
#  'Tariff rate, most favored nation, weighted mean, primary products (%)',
#  'Tariff rate, applied, weighted mean, primary products (%)',
#  'Tariff rate, most favored nation, simple mean, primary products (%)',
#  'Tariff rate, applied, simple mean, primary products (%)',
#  'Share of tariff lines with international peaks, primary products (%)',
#  'Tariff rate, most favored nation, weighted mean, all products (%)',
#  'Tariff rate, applied, weighted mean, all products (%)',
#  'Tariff rate, most favored nation, simple mean, all products (%)',
#  'Tariff rate, applied, simple mean, all products (%)',
#  'Share of tariff lines with international peaks, all products (%)',
#  'Bound rate, simple mean, all products (%)',
#  'Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#  'Tariff rate, applied, weighted mean, manufactured products (%)',
#  'Tariff rate, most favored nation, simple mean, manufactured products (%)',
#  'Tariff rate, applied, simple mean, manufactured products (%)',
#  'Individuals using the Internet (% of population)',
#  'Fixed telephone subscriptions (per 100 people)',
#  'Fixed telephone subscriptions',
#  'Mobile cellular subscriptions (per 100 people)',
#  'Mobile cellular subscriptions',
#  'Air transport, passengers carried',
#  'Air transport, freight (million ton-km)',
#  'Air transport, registered carrier departures worldwide',
#  'Trademark applications, total',
#  'Trademark applications, direct resident',
#  'Net official flows from UN agencies, UNFPA (current US$)',
#  'Transport services (% of service imports, BoP)',
#  'Imports of goods, services and primary income (BoP, current US$)',
#  'Charges for the use of intellectual property, payments (BoP, current US$)',
#  'Service imports (BoP, current US$)',
#  'Goods imports (BoP, current US$)',
#  'Insurance and financial services (% of service imports, BoP)',
#  'Imports of goods and services (BoP, current US$)',
#  'Primary income payments (BoP, current US$)',
#  'Communications, computer, etc. (% of service imports, BoP)',
#  'Trade in services (% of GDP)',
#  'Cereal yield (kg per hectare)',
#  'Livestock production index (2004-2006 = 100)',
#  'Food production index (2004-2006 = 100)',
#  'Crop production index (2004-2006 = 100)',
#  'Cereal production (metric tons)',
#  'Forest area (% of land area)',
#  'Forest area (sq. km)',
#  'Permanent cropland (% of land area)',
#  'Land under cereal production (hectares)',
#  'Arable land (% of land area)',
#  'Arable land (hectares per person)',
#  'Arable land (hectares)',
#  'Agricultural land (% of land area)',
#  'Agricultural land (sq. km)',
#  'Import volume index (2000 = 100)',
#  'Merchandise trade (% of GDP)',
#  'International tourism, expenditures (% of total imports)',
#  'International tourism, expenditures (current US$)',
#  'International tourism, expenditures for travel items (current US$)',
#  'International tourism, receipts for travel items (current US$)',
#  'International tourism, expenditures for passenger transport items (current US$)',
#  'International tourism, receipts for passenger transport items (current US$)',
#  'International tourism, receipts (% of total exports)',
#  'International tourism, receipts (current US$)',
#  'International tourism, number of departures',
#  'International tourism, number of arrivals',
#  'Urban population (% of total)',
#  'Urban population',
#  'Urban population growth (annual %)',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Rural population',
#  'Population, male (% of total)',
#  'Population, male',
#  'Population, female (% of total)',
#  'Population, female',
#  'Population, total',
#  'Technicians in R&D (per million people)',
#  'Researchers in R&D (per million people)',
#  'Population growth (annual %)',
#  'Age dependency ratio, young (% of working-age population)',
#  'Age dependency ratio, old (% of working-age population)',
#  'Age dependency ratio (% of working-age population)',
#  'Population ages 80 and above, male (% of male population)',
#  'Population ages 80 and above, female (% of female population)',
#  'Population ages 75-79, male (% of male population)',
#  'Population ages 75-79, female (% of female population)',
#  'Population ages 70-74, male (% of male population)',
#  'Population ages 70-74, female (% of female population)',
#  'Population ages 65 and above (% of total)',
#  'Population ages 65 and above, total',
#  'Population ages 65 and above, male (% of total)',
#  'Population ages 65 and above, male',
#  'Population ages 65 and above, female (% of total)',
#  'Population ages 65 and above, female',
#  'Population ages 65-69, male (% of male population)',
#  'Population ages 65-69, female (% of female population)',
#  'Population ages 60-64, male (% of male population)',
#  'Population ages 60-64, female (% of female population)',
#  'Population ages 55-59, male (% of male population)',
#  'Population ages 55-59, female (% of female population)',
#  'Population ages 50-54, male (% of male population)',
#  'Population ages 50-54, female (% of female population)',
#  'Population ages 45-49, male (% of male population)',
#  'Population ages 45-49, female (% of female population)',
#  'Patent applications, residents',
#  'Patent applications, nonresidents',
#  'Industrial design applications, resident, by count',
#  'Industrial design applications, nonresident, by count',
#  'Public private partnerships investment in water and sanitation (current US$)',
#  'Public private partnerships investment in transport (current US$)',
#  'Public private partnerships investment in energy (current US$)',
#  'Investment in water and sanitation with private participation (current US$)',
#  'Investment in transport with private participation (current US$)',
#  'Investment in energy with private participation (current US$)',
#  'Net official flows from UN agencies, UNDP (current US$)',
#  'Net official flows from UN agencies, UNICEF (current US$)',
#  'Net financial flows, RDB nonconcessional (NFL, current US$)',
#  'Net financial flows, RDB concessional (NFL, current US$)',
#  'PPG, private creditors (NFL, current US$)',
#  'PPG, other private creditors (NFL, current US$)',
#  'PNG, commercial banks and other creditors (NFL, current US$)',
#  'PNG, bonds (NFL, current US$)',
#  'Commercial banks and other lending (PPG + PNG) (NFL, current US$)',
#  'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#  'Unemployment, total (% of total labor force) (national estimate)',
#  'Unemployment, male (% of male labor force) (modeled ILO estimate)',
#  'Unemployment, male (% of male labor force) (national estimate)',
#  'Unemployment, female (% of female labor force) (modeled ILO estimate)',
#  'Unemployment, female (% of female labor force) (national estimate)',
#  'Share of youth not in education, employment or training, total (% of youth population)',
#  'Share of youth not in education, employment or training, male (% of male youth population)',
#  'Share of youth not in education, employment or training, female (% of female youth population)',
#  'Unemployment with intermediate education (% of total labor force with intermediate education)',
#  'Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#  'Unemployment with intermediate education, female (% of female labor force with intermediate education)',
#  'Unemployment with basic education (% of total labor force with basic education)',
#  'Unemployment with basic education, male (% of male labor force with basic education)',
#  'Unemployment with basic education, female (% of female labor force with basic education)',
#  'Unemployment with advanced education (% of total labor force with advanced education)',
#  'Unemployment with advanced education, male (% of male labor force with advanced education)',
#  'Unemployment with advanced education, female (% of female labor force with advanced education)',
#  'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#  'Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#  'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#  'Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#  'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#  'Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#  'Labor force, total',
#  'Labor force, female (% of total labor force)',
#  'Labor force with intermediate education (% of total working-age population with intermediate education)',
#  'Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#  'Labor force with intermediate education, female (% of female working-age population with intermediate education)',
#  'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#  'Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#  'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#  'Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#  'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#  'Ratio of female to male labor force participation rate (%) (national estimate)',
#  'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#  'Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#  'Labor force with basic education (% of total working-age population with basic education)',
#  'Labor force with basic education, male (% of male working-age population with basic education)',
#  'Labor force with basic education, female (% of female working-age population with basic education)',
#  'Labor force with advanced education (% of total working-age population with advanced education)',
#  'Labor force with advanced education, male (% of male working-age population with advanced education)',
#  'Labor force with advanced education, female (% of female working-age population with advanced education)',
#  'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#  'Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#  'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#  'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#  'Labor force participation rate for ages 15-24, total (%) (national estimate)',
#  'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#  'Labor force participation rate for ages 15-24, male (%) (national estimate)',
#  'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#  'Labor force participation rate for ages 15-24, female (%) (national estimate)',
#  'Employment in services (% of total employment) (modeled ILO estimate)',
#  'Employment in services, male (% of male employment) (modeled ILO estimate)',
#  'Domestic credit to private sector (% of GDP)',
#  'Domestic credit provided by financial sector (% of GDP)',
#  'Wholesale price index (2010 = 100)',
#  'Inflation, consumer prices (annual %)',
#  'Consumer price index (2010 = 100)',
#  'Total reserves minus gold (current US$)',
#  'Total reserves in months of imports',
#  'Total reserves (% of total external debt)',
#  'Total reserves (includes gold, current US$)']

# %%
# Self Improvement and Employment 
myPlt = bra.plot(y = ['Share of youth not in education, employment or training, total (% of youth population)',
                      'Unemployment, total (% of total labor force) (modeled ILO estimate)'])
myPlt.locator_params(integer=True)
plt.xlabel('Year')
plt.ylabel('%')
plt.title('Self Improvement and Employment')
plt.legend(loc = 6)
plt.show()

# %%
# Self Improvement and Employment 
myPlt = bra.plot(y = ['Wholesale price index (2010 = 100)',
 'Consumer price index (2010 = 100)'])
myPlt.locator_params(integer=True)
plt.xlabel('Year')
plt.ylabel('Index')
plt.title('Wholesale and Consumer Prices')
plt.legend(loc = 2)
plt.show()

bra['Inflation, consumer prices (annual %)'].plot(kind = 'bar')
plt.title('Inflation, consumer prices')
plt.xlabel('Year')
plt.ylabel('%')
plt.show()

price = bra[['Wholesale price index (2010 = 100)', 'Consumer price index (2010 = 100)']]
inf = bra[['Inflation, consumer prices (annual %)']]

print('inflation 2003:')
print(str(bra['Inflation, consumer prices (annual %)'].loc[2003]) + ' %')
# pd.DataFrame(price.values*(inf.values/100), columns=price.columns, index=price.index).plot()
# Out:
# inflation 2003:
# 14.71491972 %

# %%
#Check Correlation of some fields

import seaborn as sb

c = bra[['Service exports (BoP, current US$)',
 'Goods exports (BoP, current US$)',
 'Ores and metals imports (% of merchandise imports)',
 'Manufactures imports (% of merchandise imports)',
 'Livestock production index (2004-2006 = 100)',
 'Food production index (2004-2006 = 100)',
 'Crop production index (2004-2006 = 100)',
 'Public private partnerships investment in water and sanitation (current US$)',
 'Public private partnerships investment in transport (current US$)',
 'Public private partnerships investment in energy (current US$)',
 'Investment in water and sanitation with private participation (current US$)',
 'Investment in transport with private participation (current US$)',
 'Investment in energy with private participation (current US$)']]

corr = c.corr(method='pearson')
corr.head()
# Out:
#                                                     Service exports (BoP, current US$)  \
# Service exports (BoP, current US$)                                            1.000000
# Goods exports (BoP, current US$)                                              0.982269
# Ores and metals imports (% of merchandise imports)                            0.039205
# Manufactures imports (% of merchandise imports)                              -0.141301
# Livestock production index (2004-2006 = 100)                                  0.951092
#
#                                                     Goods exports (BoP, current US$)  \
# Service exports (BoP, current US$)                                          0.982269
# Goods exports (BoP, current US$)                                            1.000000
# Ores and metals imports (% of merchandise imports)                          0.137807
# Manufactures imports (% of merchandise imports)                            -0.244517
# Livestock production index (2004-2006 = 100)                                0.935439
#
#                                                     Ores and metals imports (% of merchandise imports)  \
# Service exports (BoP, current US$)                                                           0.039205
# Goods exports (BoP, current US$)                                                             0.137807
# Ores and metals imports (% of merchandise imports)                                           1.000000
# Manufactures imports (% of merchandise imports)                                             -0.742677
# Livestock production index (2004-2006 = 100)                                                 0.174144
#
#                                                     Manufactures imports (% of merchandise imports)  \
# Service exports (BoP, current US$)                                                        -0.141301
# Goods exports (BoP, current US$)                                                          -0.244517
# Ores and metals imports (% of merchandise imports)                                        -0.742677
# Manufactures imports (% of merchandise imports)                                            1.000000
# Livestock production index (2004-2006 = 100)                                              -0.182626
#
#                                                     Livestock production index (2004-2006 = 100)  \
# Service exports (BoP, current US$)                                                      0.951092
# Goods exports (BoP, current US$)                                                        0.935439
# Ores and metals imports (% of merchandise imports)                                      0.174144
# Manufactures imports (% of merchandise imports)                                        -0.182626
# Livestock production index (2004-2006 = 100)                                            1.000000
#
#                                                     Food production index (2004-2006 = 100)  \
# Service exports (BoP, current US$)                                                 0.960034
# Goods exports (BoP, current US$)                                                   0.938160
# Ores and metals imports (% of merchandise imports)                                 0.116455
# Manufactures imports (% of merchandise imports)                                   -0.134656
# Livestock production index (2004-2006 = 100)                                       0.994777
#
#                                                     Crop production index (2004-2006 = 100)  \
# Service exports (BoP, current US$)                                                 0.961990
# Goods exports (BoP, current US$)                                                   0.936163
# Ores and metals imports (% of merchandise imports)                                 0.091729
# Manufactures imports (% of merchandise imports)                                   -0.110899
# Livestock production index (2004-2006 = 100)                                       0.988082
#
#                                                     Public private partnerships investment in water and sanitation (current US$)  \
# Service exports (BoP, current US$)                                                           0.588705
# Goods exports (BoP, current US$)                                                             0.567924
# Ores and metals imports (% of merchandise imports)                                          -0.263806
# Manufactures imports (% of merchandise imports)                                             -0.027094
# Livestock production index (2004-2006 = 100)                                                 0.487461
#
#                                                     Public private partnerships investment in transport (current US$)  \
# Service exports (BoP, current US$)                                                           0.613633
# Goods exports (BoP, current US$)                                                             0.565552
# Ores and metals imports (% of merchandise imports)                                          -0.273877
# Manufactures imports (% of merchandise imports)                                             -0.123315
# Livestock production index (2004-2006 = 100)                                                 0.456570
#
#                                                     Public private partnerships investment in energy (current US$)  \
# Service exports (BoP, current US$)                                                           0.543097
# Goods exports (BoP, current US$)                                                             0.506933
# Ores and metals imports (% of merchandise imports)                                          -0.274393
# Manufactures imports (% of merchandise imports)                                              0.162989
# Livestock production index (2004-2006 = 100)                                                 0.366977
#
#                                                     Investment in water and sanitation with private participation (current US$)  \
# Service exports (BoP, current US$)                                                           0.543174
# Goods exports (BoP, current US$)                                                             0.519861
# Ores and metals imports (% of merchandise imports)                                          -0.291004
# Manufactures imports (% of merchandise imports)                                              0.010960
# Livestock production index (2004-2006 = 100)                                                 0.429278
#
#                                                     Investment in transport with private participation (current US$)  \
# Service exports (BoP, current US$)                                                           0.614452
# Goods exports (BoP, current US$)                                                             0.565427
# Ores and metals imports (% of merchandise imports)                                          -0.273193
# Manufactures imports (% of merchandise imports)                                             -0.123687
# Livestock production index (2004-2006 = 100)                                                 0.457930
#
#                                                     Investment in energy with private participation (current US$)
# Service exports (BoP, current US$)                                                           0.544858
# Goods exports (BoP, current US$)                                                             0.510141
# Ores and metals imports (% of merchandise imports)                                          -0.278249
# Manufactures imports (% of merchandise imports)                                              0.156572
# Livestock production index (2004-2006 = 100)                                                 0.363847

# %%
# plot a correlation with a heat map
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = 1
sb.heatmap(corr, mask=mask)

# %%
#Get a closer look at the correlation between private investments and service and production indicators

cSnap = corr[['Service exports (BoP, current US$)',
 'Goods exports (BoP, current US$)',
 'Ores and metals imports (% of merchandise imports)',
 'Manufactures imports (% of merchandise imports)',
 'Livestock production index (2004-2006 = 100)',
 'Food production index (2004-2006 = 100)',
 'Crop production index (2004-2006 = 100)']].loc[['Public private partnerships investment in water and sanitation (current US$)',
 'Public private partnerships investment in transport (current US$)',
 'Public private partnerships investment in energy (current US$)',
 'Investment in water and sanitation with private participation (current US$)',
 'Investment in transport with private participation (current US$)',
 'Investment in energy with private participation (current US$)']]

cmap = sb.diverging_palette(255, 133, l=60, n=7, center="dark", as_cmap=True)
sb.heatmap(cSnap, cmap=cmap)

# %%
labels = {
 'Service exports (BoP, current US$)':'SE',
 'Goods exports (BoP, current US$)':'GE',
 'Ores and metals imports (% of merchandise imports)':'OnMI',
 'Manufactures imports (% of merchandise imports)':'MI',
 'Livestock production index (2004-2006 = 100)':'LPi',
 'Food production index (2004-2006 = 100)':'FPi',
 'Crop production index (2004-2006 = 100)':'CPi',
 'Public private partnerships investment in water and sanitation (current US$)':'PPPI WS',
 'Public private partnerships investment in transport (current US$)':'PPPI T',
 'Public private partnerships investment in energy (current US$)':'PPPI E',
 'Investment in water and sanitation with private participation (current US$)':'IWSwPP',
 'Investment in transport with private participation (current US$)':'ITwPP',
 'Investment in energy with private participation (current US$)':'IEwPP'
}

# %%
corr = c.corr(method='pearson')
corr = corr.rename(labels, axis=1)
sb.heatmap(corr, mask=mask).set_title('Pearson Correlation')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation')

# %%
corr = c.corr(method='kendall')
corr = corr.rename(labels, axis=1)
sb.heatmap(corr, mask=mask).set_title('Kendall Correlation')
# Out:
# Text(0.5, 1.0, 'Kendall Correlation')

# %%
corr = c.corr(method='spearman')
corr = corr.rename(labels, axis=1)
(sb.heatmap(corr, mask=mask)).set_title('Spearman Correlation')
# Out:
# Text(0.5, 1.0, 'Spearman Correlation')

# %%
# Linear Regression

x = np.array(c['Service exports (BoP, current US$)'])
y = np.array(c['Livestock production index (2004-2006 = 100)'])

pf = np.polyfit(x, y, 1)
pf2 = np.polyfit(x, y, 2)
pf3 = np.polyfit(x, y, 3)
print(pf, '\n', pf2, '\n', pf3, '\n')
# Out:
# [1.55432996e-09 6.82716006e+01]
#  [-3.87316440e-20  3.28534055e-09  5.49993859e+01]
#  [ 2.81143081e-30 -2.35684791e-19  7.28278282e-09  3.38827157e+01]

# %%
fig = plt.figure(figsize=(8, 15))

ax1 = fig.add_subplot(311)
ax1.plot(x,y,'^')
ax1 = plt.plot(x, np.polyval(pf,x))
ax1 = plt.title('First-order')

ax2 = fig.add_subplot(312)
ax2.plot(x,y,'^')
ax2 = plt.plot(x, np.polyval(pf2,x))
ax2 = plt.title('Second-order')

ax3 = fig.add_subplot(313)
ax3.plot(x,y,'^')
ax3 = plt.plot(x, np.polyval(pf3,x))
ax3= plt.title('Third-order')


#plt.title('Linear Regression')
